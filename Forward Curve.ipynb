# %%
import numpy as np

# %%
TM1=[44,43,42,41,40,37,36,35,34,33,30]

# %%
TM2=[410,409,408,407,406,403,402,401,400,399,396]

# %%
TM3=[594,593,592,591,590,587,586,585,584,583,580]

# %%
TM4=[867,866,865,864,863,860,859,858,857,856,853]

# %%
TM5=[2327,2326,2325,2324,2323,2320,2319,2318,2317,2316,2313]

# %%
TM6=[2511,2510,2509,2508,2507,2504,2503,2502,2501,2500,2497]

# %%
TM7=[3241,3240,3239,3238,3237,3234,3233,3232,3231,3230,3227]

# %%
P1=[101.03,101.0317855,101.0613323,101.07,101.100426,101.1390666,101.1586134,101.1781603,101.1977071,101.217254,101.2358945]

# %%
P2=[99.62,99.5724924,99.66469664,99.65,99.60910514,99.63571788,99.65792212,99.72012637,99.73233062,99.66453486,99.6411476]

# %%
P31=[93.48,93.60178466,94.00724548,94.06,93.72816712,93.69454959,93.71001041,93.85547123,93.85093205,93.58639288,93.46277534]

# %%
P32=[97.61,97.59026918,97.72844315,97.66,97.5647911,97.58931301,97.58748699,97.67566096,97.69383493,97.5120089,97.48653082]

# %%
P3=[(P31[i]+P32[i])/2 for i in range(11)]

# %%
P3
# Out:
# [95.545,
#  95.59602692000001,
#  95.867844315,
#  95.86,
#  95.64647911,
#  95.6419313,
#  95.6487487,
#  95.765566095,
#  95.77238349,
#  95.54920089000001,
#  95.47465308]

# %%
P4=[95.70,95.74410616,95.94092945,95.93,95.78457603,95.74504589,95.71186918,95.84869247,95.88551575,95.69233904,95.6028089]

# %%
P5=[97.38,97.48532363,98.18764623,98.18,97.49229144,97.45925925,97.49158185,97.72390445,97.61622705,97.09854966,96.91551747]

# %%
P6=[97.23,97.39315685,98.07543384,98.08,97.39998781,97.28681877,97.32909575,97.51137274,97.41364973,96.88592671,96.69275767]

# %%
P7=[89.74,89.90225137,90.71029877,90.72,89.91639356,89.85053575,89.98858315,90.22663055,90.10467795,89.66272534,89.50686753]

# %%
import math

# %%
DLOGP21=[math.log(P2[i])-math.log(P1[i]) for i in range(11)]

# %%
DLOGP31=[math.log(P3[i])-math.log(P1[i]) for i in range(11)]

# %%
DLOGP41=[math.log(P4[i])-math.log(P1[i]) for i in range(11)]

# %%
DLOGP51=[math.log(P5[i])-math.log(P1[i]) for i in range(11)]

# %%
DLOGP61=[math.log(P6[i])-math.log(P1[i]) for i in range(11)]

# %%
DLOGP71=[math.log(P6[i])-math.log(P1[i]) for i in range(11)]

# %%
DTM21=[TM2[i]-TM1[i] for i in range(11)]

# %%
DTM31=[TM3[i]-TM1[i] for i in range(11)]

# %%
DTM41=[TM4[i]-TM1[i] for i in range(11)]

# %%
DTM51=[TM5[i]-TM1[i] for i in range(11)]

# %%
DTM61=[TM6[i]-TM1[i] for i in range(11)]

# %%
DTM71=[TM7[i]-TM1[i] for i in range(11)]

# %%
FR21=[-365*DLOGP21[i]/DTM21[i] for i in range(11)]

# %%
FR21
# Out:
# [0.014016154371567658,
#  0.014509477535909868,
#  0.013878042626364736,
#  0.01411064013971365,
#  0.01482015901148601,
#  0.014934835901642365,
#  0.014905335227181054,
#  0.014475740784719976,
#  0.014546343049587091,
#  0.015417102625447045,
#  0.0158347919192833]

# %%
import matplotlib.pyplot as plt

# %%
for i in range(len(TM2)):
    plt.plot(TM2[i:i+2], FR21[i:i+2], 'go-')

plt.show()

# %%
FR31=[-365*DLOGP31[i]/DTM31[i] for i in range(11)]

# %%
for i in range(len(TM3)):
    plt.plot(TM3[i:i+2], FR31[i:i+2], 'go-')

plt.show()

# %%
FR41=[-365*DLOGP41[i]/DTM41[i] for i in range(11)]

# %%
for i in range(len(TM4)):
    plt.plot(TM4[i:i+2], FR41[i:i+2], 'go-')

plt.show()

# %%
FR51=[-365*DLOGP51[i]/DTM51[i] for i in range(11)]

# %%
for i in range(len(TM5)):
    plt.plot(TM5[i:i+2], FR51[i:i+2], 'go-')

plt.show()

# %%
FR61=[-365*DLOGP61[i]/DTM61[i] for i in range(11)]

# %%
for i in range(len(TM6)):
    plt.plot(TM6[i:i+2], FR61[i:i+2], 'go-')

plt.show()

# %%
FR71=[-365*DLOGP71[i]/DTM71[i] for i in range(11)]

# %%
for i in range(len(TM6)):
    plt.plot(TM6[i:i+2], FR61[i:i+2], 'go-')

plt.show()

# %%
for i in range(len(TM2+TM3+TM4+TM5+TM6+TM7)):
    plt.plot((TM2+TM3+TM4+TM5+TM6+TM7)[i:i+2], (FR21+FR31+FR41+FR51+FR61+FR71)[i:i+2], 'go-')
plt.title("Forward Curve")
plt.xlabel("Days to Maturities")
plt.ylabel("Forward Rates")
plt.show()

# %%
FR21
# Out:
# [0.014016154371567658,
#  0.014509477535909868,
#  0.013878042626364736,
#  0.01411064013971365,
#  0.01482015901148601,
#  0.014934835901642365,
#  0.014905335227181054,
#  0.014475740784719976,
#  0.014546343049587091,
#  0.015417102625447045,
#  0.0158347919192833]

# %%
FR31
# Out:
# [0.037044289158912086,
#  0.03670168935894781,
#  0.03501143821871434,
#  0.035122657472011674,
#  0.03680225623440437,
#  0.03708740511654154,
#  0.037168348831096425,
#  0.03648655553753295,
#  0.03656751080530944,
#  0.03824398924946657,
#  0.03888416886269016]

# %%
FR41
# Out:
# [0.024037314037627378,
#  0.023840799265995798,
#  0.02305970619840961,
#  0.02314826773839705,
#  0.023954586076502724,
#  0.02430712849798196,
#  0.024546537862667264,
#  0.02399868270856358,
#  0.02391400344485177,
#  0.02489406127900722,
#  0.025390864114113634]

# %%
FR51
# Out:
# [0.005882951320655476,
#  0.005712951134175729,
#  0.004612010455562273,
#  0.00463817274274313,
#  0.005810107242313966,
#  0.005925379301161868,
#  0.005903260340754441,
#  0.005553615720044503,
#  0.00576075824813062,
#  0.006641752599560965,
#  0.006972848983761079]

# %%
FR61
# Out:
# [0.005672250411673054,
#  0.005426800660354019,
#  0.004437208593113673,
#  0.004443009312125842,
#  0.005516908298790653,
#  0.005745451653476637,
#  0.005709762743476132,
#  0.005461523194319898,
#  0.005638452191272143,
#  0.0064707181112172605,
#  0.006793242977230736]

# %%
FR71
# Out:
# [0.004377054039911612,
#  0.004187650056019195,
#  0.003424020518990126,
#  0.0034284967072300446,
#  0.0042571826002866875,
#  0.004433540578394389,
#  0.004406000840836916,
#  0.004214444078945007,
#  0.004350973273652917,
#  0.004993200369212694,
#  0.005242080207953777]
