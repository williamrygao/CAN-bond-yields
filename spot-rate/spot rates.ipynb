# %%
TM1=[44,43,42,41,40,37,36,35,34,33,30]

# %%
r1=[0.000061173, 0.0000625957, 0.000064086, 0.0000656491, 0.0000672903,
0.0000727463, 0.000074767, 0.0000769032, 0.0000791651, 0.000081564,
0.0000897204]

# %%
TM2=[228,227,226,225,224,221,220,219,218,217,214]

# %%
r2=[0.0000638287, 0.0000652142, 0.0000648845, 0.0000659296,
0.0000673452, 0.0000699798, 0.0000705422, 0.0000710634, 0.0000721174,
0.0000743456, 0.0000789702]

# %%
TM3=[410,409,408,407,406,405,403,402,401,399,396]

# %%
r3=[0.0000664844, 0.0000678327, 0.0000656829, 0.0000662101,
0.0000674001, 0.0000672133, 0.0000663173, 0.0000652236, 0.0000650697,
0.0000671272, 0.00006822]

# %%
TM4=[594,593,592,591,590,587,586,585,584,583,580]

# %%
r4=[0.000112694, 0.000111935, 0.000107205, 0.000107507, 0.00011157,
0.000112231, 0.0001123, 0.00011036, 0.000110428, 0.000114698,
0.000116668]

# %%
TM5=[867,866,865,864,863,860,859,858,857,856,853]

# %%
r5=[0.000082859, 0.000082405, 0.0000800977, 0.0000803203, 0.0000821896, 
0.0000829615, 0.000083474, 0.0000818761, 0.0000815099, 0.0000839882, 
0.0000853847]

# %%
TM6=[1050,1049,1048,1047,1046,1043,1042,1041,1040,1039,1036]

# %%
r6=[0.00008178195139112714, 0.00008132574186964698,0.00007889357795014519, 0.00007909583379677486,0.00008114645858173306, 0.00008185148806817495,0.00008228269940075042, 0.00008075302054976456, 0.0000805039858336972, 0.0000829837835891325,0.00008432503200631904]

# %%
TM7=[1232,1231,1230,1229,1228,1225,1224,1223,1222,1221,1218]

# %%
r7=[0.0000807049, 0.0000802465, 0.0000776895, 0.0000778713,
0.0000801033, 0.0000807415, 0.0000810914, 0.00007963, 0.0000794981,
0.0000819794, 0.0000832653]

# %%
TM8=[1415,1414,1413,1412,1411,1408,1407,1406,1405,1404,1401]

# %%
r8=[0.0000796278, 0.0000791672, 0.0000764854, 0.0000766468, 
0.0000790602, 0.0000796315, 0.0000799001, 0.0000785069, 0.0000784922, 
0.0000809749, 0.0000822056]

# %%
TM9=[1597,1596,1595,1594,1593,1590,1589,1588,1587,1586,1583]

# %%
r9=[0.0000785508, 0.0000780879, 0.0000752813, 0.0000754223, 0.000078017, 
0.0000785215, 0.0000787088, 0.0000773839, 0.0000774864, 0.0000799705, 
0.0000811459]

# %%
TM10=[1780,1779,1778,1777,1776,1773,1772,1771,1770,1769,1766]

# %%
r10=[0.0000774737, 0.0000770086, 0.0000740772, 0.0000741978, 
0.0000769739, 0.0000774115, 0.0000775175, 0.0000762608, 0.0000764805, 
0.0000789661, 0.0000800862]

# %%
TM11=[1963,1962,1961,1960,1959,1956,1955,1954,1953,1952,1949]

# %%
r11=[0.0000763966, 0.0000759293, 0.0000728732, 0.0000729733, 
0.0000759308, 0.0000763015, 0.0000763262, 0.0000751378, 0.0000754746, 
0.0000779617, 0.0000790265]

# %%
TM12=[2146,2145,2144,2143,2142,2139,2138,2137,2136,2135,2132]

# %%
r12=[0.0000753196, 0.00007485, 0.0000716691, 0.0000717488, 0.0000748876, 
0.0000751915, 0.0000751349, 0.0000740147, 0.0000744688, 0.0000769572, 
0.0000779668]

# %%
TM13=[2328,2327,2326,2325,2324,2321,2320,2319,2318,2317,2314]

# %%
r13=[0.0000742425, 0.0000737707, 0.000070465, 0.0000705243, 0.0000738445, 
0.0000740815, 0.0000739436, 0.0000728917, 0.0000734629, 0.0000759528, 
0.0000769071]

# %%
TM14=[2511,2510,2509,2508,2507,2504,2503,2502,2501,2500,2497]

# %%
r14=[0.0000722579, 0.000070422867, 0.0000685727, 0.0000685697, 
0.0000716116, 0.0000722093, 0.0000720332, 0.0000712936, 0.0000717758, 
0.0000741347, 0.0000750669]

# %%
TM15=[2693,2692,2691,2690,2689,2686,2685,2684,2683,2682,2679]

# %%
r15=[0.000064713, 0.0000622109, 0.0000612527, 0.0000612485, 0.0000640986, 
0.000064652, 0.0000644859, 0.0000637873, 0.000064236, 0.0000664474, 
0.0000673164]

# %%
TM16=[2876,2875,2874,2873,2872,2869,2868,2867,2866,2865,2862]

# %%
r16=[0.000057168, 0.0000421352, 0.0000539327, 0.0000539274, 0.0000565857, 
0.0000570948, 0.0000569386, 0.0000562809, 0.0000566961, 0.0000587601, 
0.0000595658]

# %%
TM17=[3058,3057,3056,3055,3054,3051,3050,3049,3048,3047,3044]

# %%
r17=[0.0000496231, 0.0000420594, 0.0000466128, 0.0000466062, 
0.0000490727, 0.0000495375, 0.0000493912, 0.0000487746, 0.0000491563, 
0.0000510727, 0.0000518153]

# %%
TM18=[3241,3240,3239,3238,3237,3234,3233,3232,3231,3230,3227]

# %%
r18=[0.0000420781, 0.0000419836, 0.0000392928, 0.000039285, 0.0000415597, 
0.0000419802, 0.0000418439, 0.0000412683, 0.0000416164, 0.0000433854, 
0.0000440648]

# %%
import matplotlib.pyplot as plt

# %%
scaledrates=[365*r for r in (r1+r2+r3+r3+r5+r6+r7+r8+r9+r10+r11+r12+r13+r14+r15+r16+r17+r18)]

# %%
for i in range(len(TM1+TM2+TM3+TM3+TM5+TM6+TM7+TM8+TM9+TM10+TM11+TM12+TM13+TM14+TM15+TM16+TM17+TM18)):
    plt.plot((TM1+TM2+TM3+TM3+TM5+TM6+TM7+TM8+TM9+TM10+TM11+TM12+TM13+TM14+TM15+TM16+TM17+TM18)[i:i+2], (r1+r2+r3+r3+r5+r6+r7+r8+r9+r10+r11+r12+r13+r14+r15+r16+r17+r18)[i:i+2], 'ro-')

plt.show()

# %%
for i in range(len(TM1+TM2+TM3+TM3+TM5+TM6+TM7+TM8+TM9+TM10+TM11+TM12+TM13+TM14+TM15+TM16+TM17+TM18)):
    plt.plot((TM1+TM2+TM3+TM3+TM5+TM6+TM7+TM8+TM9+TM10+TM11+TM12+TM13+TM14+TM15+TM16+TM17+TM18)[i:i+2], scaledrates[i:i+2], 'ro-')
plt.title("Spot Curve")
plt.xlabel("Days to Maturities")
plt.ylabel("Spot Rates")
plt.show()

# %%
for i in range(len(TM15)):
    plt.plot((TM15)[i:i+2], (r15)[i:i+2], 'ro-')

plt.show()
